# %% [markdown]
# ## introduction :
#   - Dans ce document nous allons presenter les finctions de visualisation de données les plus connues ,en utilisant la bibliotheque seaborn en python , il est à noter que ce document a ete cree suite à une formation de data visualization sous la platforme  <a>kaggle.com</a>

# %% [markdown]
# # pour installer seaborn sur jupyter utilisez cette commande :
#    - !pip install seaborn

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
fifa_filepath = "./flight_delays.csv"
data = pd.read_csv(fifa_filepath, index_col="Month", parse_dates=True)

# %%
data.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# ...

# %% [markdown]
# ## Line plot with seaborn :

# %%
# Change the style of the figure to the "dark" theme
sns.set_style("dark")
plt.figure(figsize=(16,6))
# Line chart showing how FIFA rankings evolved over time 
sns.lineplot(data=data)
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
sns.lineplot(data=data)
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# ## Scatter with seaborn :

# %%
sns.scatterplot(x=data['AS'], y=data['UA'])
# Out:
# <AxesSubplot:xlabel='AS', ylabel='UA'>

# %% [markdown]
# ## Scatter & regression with seaborn :

# %%
sns.regplot(x=data['AS'], y=data['UA']) 
#ajouter la ligne de regression au scatter
# Out:
# <AxesSubplot:xlabel='AS', ylabel='UA'>

# %%
sns.scatterplot(x=data['AS'], y=data['UA'], hue=data['EV'])
#filter with hue un attribut (ses valeurs vont destinguer les points (x,y) avec des couleurs differentes)
# Out:
# <AxesSubplot:xlabel='AS', ylabel='UA'>

# %% [markdown]
# ## Implot in seaborn :

# %%
sns.lmplot(x="AS", y="UA", hue="EV", data=data)
#ajouter les lignes de refression selon hue (nombre de valeurs destincts de EV=nbr de lignes de regressions)

# %% [markdown]
# ## swarmplot in seaborn :

# %%
sns.swarmplot(x=data['AS'],
              y=data['UA'])
# Out:
# <AxesSubplot:xlabel='AS', ylabel='UA'>

# %% [markdown]
# ## histogramme in seaborn :

# %%
sns.histplot(data['VX'])
#histogramme de valeurs
# sns.histplot(data=data, x='Petal Length (cm)', hue='Species')
#hue filter
# Out:
# <AxesSubplot:xlabel='VX', ylabel='Count'>

# %% [markdown]
# ## features detribution with seaborn (KDE):
# ### (like smoothed hist):

# %%
sns.kdeplot(data=data['VX'], shade=True)
#densite d'une caracteristique ,shade = true :pour colrer surface under curve
# Out:
# <AxesSubplot:xlabel='VX', ylabel='Density'>

# %% [markdown]
# ## diagramme de bars in seaborn:

# %%
plt.figure(figsize=(25,15))
sns.barplot(x=data['AS'], y=data['UA']) 
#diaframme de bars
# Out:
# <AxesSubplot:xlabel='AS', ylabel='UA'>

# %% [markdown]
# ## heatmap in seaborn :

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data=data, annot=True) 
# annot=true pour afficher la valeur de la cellule
# Out:
# <AxesSubplot:ylabel='Month'>
